# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.06228444 2.77490353 2.4829937  2.39541827 2.17998285 2.56185004
#  2.89530086 2.1216577  2.96394497 2.22287816]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def uniform_(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    a = bottom
    b = ceiling
    randoms = a + (b-a)*x
    return randoms
params = uniform_(10, 15, 100)
params_2 = uniform_(10, 60, 1000)
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.hist(params)
ax2.hist(params_2)
# Out:
# (array([115., 100., 103., 101.,  96.,  93., 102., 102.,  93.,  95.]),
#  array([10.01610767, 15.01429595, 20.01248424, 25.01067252, 30.0088608 ,
#         35.00704908, 40.00523736, 45.00342564, 50.00161393, 54.99980221,
#         59.99799049]),
#  <BarContainer object of 10 artists>)

# %%
params = uniform_(10, 15, 100)
params_2 = uniform_(10, 60, 1000)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.hist(params)
ax2.hist(params_2)
# Out:
# (array([ 95., 112.,  91., 118., 101.,  90.,  98.,  94., 100., 101.]),
#  array([10.02599954, 15.01974872, 20.0134979 , 25.00724708, 30.00099626,
#         34.99474544, 39.98849462, 44.9822438 , 49.97599298, 54.96974215,
#         59.96349133]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here
def normal_gen(mean, std):
    normal = norm(mean, std) 
    return normal.rvs(size=1000)

# %%
n_1 = normal_gen(10, 1)

# %%
n_2 = normal_gen(10, 50)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey = True)
ax1.hist(n_1, bins=50)
ax2.hist(n_2, bins=50)
# Out:
# (array([ 1.,  1.,  0.,  0.,  1.,  1.,  2.,  6.,  5.,  7.,  2., 10., 10.,
#         16., 21., 26., 17., 23., 22., 37., 48., 40., 51., 47., 45., 46.,
#         53., 42., 50., 46., 41., 45., 30., 42., 20., 29., 30., 20., 19.,
#         10.,  5., 10.,  7.,  7.,  3.,  0.,  0.,  4.,  0.,  2.]),
#  array([-156.7742074 , -150.47502987, -144.17585235, -137.87667483,
#         -131.57749731, -125.27831978, -118.97914226, -112.67996474,
#         -106.38078722, -100.08160969,  -93.78243217,  -87.48325465,
#          -81.18407712,  -74.8848996 ,  -68.58572208,  -62.28654456,
#          -55.98736703,  -49.68818951,  -43.38901199,  -37.08983446,
#          -30.79065694,  -24.49147942,  -18.1923019 ,  -11.89312437,
#           -5.59394685,    0.70523067,    7.00440819,   13.30358572,
#           19.60276324,   25.90194076,   32.20111829,   38.50029581,
#           44.79947333,   51.09865085,   57.39782838,   63.6970059 ,
#           69.99618342,   76.29536095,   82.59453847,   88.89371599,
#           95.19289351,  101.49207104,  107.79124856,  114.09042608,
#          120.3896036 ,  126.68878113,  132.98795865,  139.28713617,
#          145.5863137 ,  151.88549122,  158.18466874]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# The second one has a bigger variance, so the data is more spread out. In the first we can see the mean all numbers are pretty close to the mean.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
# your code here
vehicles = pd.read_csv("vehicles.csv")
vehicles
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicles["Fuel Barrels/Year"].mean()
# Out:
# 17.609055502328875

# %%
sns.histplot(data = vehicles, x = "Fuel Barrels/Year", bins = 12, kde = True)
# Out:
# <AxesSubplot:xlabel='Fuel Barrels/Year', ylabel='Count'>

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
vehicles["CO2 Emission Grams/Mile"].mean()
# Out:
# 475.31633925715045

# %%
# your code here
sns.histplot(data = vehicles, x = "CO2 Emission Grams/Mile", bins = 12, kde = True)
# Out:
# <AxesSubplot:xlabel='CO2 Emission Grams/Mile', ylabel='Count'>

# %% [markdown]
# 3. Combined MPG

# %%
vehicles["Combined MPG"].mean()
# Out:
# 19.92932242990654

# %%
vehicles["Combined MPG"].std()
# Out:
# 5.112408944666006

# %%
# your code here
sns.histplot(data = vehicles, x = "Combined MPG", bins = 50, kde = True)
# Out:
# <AxesSubplot:xlabel='Combined MPG', ylabel='Count'>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
vehicles.shape
# Out:
# (35952, 15)

# %%
from scipy.stats import shapiro 
shapiro(vehicles["Fuel Barrels/Year"])
# Out:
# /Users/narea/opt/miniconda3/envs/ironhack/lib/python3.10/site-packages/scipy/stats/_morestats.py:1800: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# ShapiroResult(statistic=0.967258095741272, pvalue=0.0)

# %%
shapiro(vehicles["CO2 Emission Grams/Mile"])
# Out:
# ShapiroResult(statistic=0.9675898551940918, pvalue=0.0)

# %%
shapiro(vehicles["Combined MPG"])
# Out:
# ShapiroResult(statistic=0.9466004967689514, pvalue=0.0)

# %% [markdown]
# None of them are normally ditributed.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
# your code here
def exp_gen(mean):
    ex = np.random.exponential(mean, 10000)
    return ex

ex_1 = exp_gen(2)
ex_2 = exp_gen(200)
fig, (ax1, ax2) = plt.subplots(1, 2, sharey = True)
ax1.hist(ex_1, bins=100)
ax2.hist(ex_2, bins=100)
# Out:
# (array([1.174e+03, 1.025e+03, 9.070e+02, 8.360e+02, 7.060e+02, 6.180e+02,
#         5.870e+02, 4.900e+02, 4.380e+02, 3.830e+02, 3.250e+02, 2.910e+02,
#         2.730e+02, 2.270e+02, 1.840e+02, 2.040e+02, 1.530e+02, 1.420e+02,
#         1.110e+02, 9.300e+01, 9.400e+01, 8.400e+01, 7.600e+01, 6.900e+01,
#         5.200e+01, 5.400e+01, 4.300e+01, 3.800e+01, 3.000e+01, 3.700e+01,
#         2.900e+01, 3.200e+01, 2.300e+01, 2.700e+01, 1.700e+01, 1.000e+01,
#         1.500e+01, 1.000e+01, 1.100e+01, 1.200e+01, 8.000e+00, 8.000e+00,
#         7.000e+00, 6.000e+00, 4.000e+00, 4.000e+00, 2.000e+00, 0.000e+00,
#         5.000e+00, 5.000e+00, 1.000e+00, 1.000e+00, 4.000e+00, 0.000e+00,
#         0.000e+00, 3.000e+00, 3.000e+00, 0.000e+00, 1.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([8.53038085e-03, 2.48910457e+01, 4.97735610e+01, 7.46560764e+01,
#         9.95385917e+01, 1.24421107e+02, 1.49303622e+02, 1.74186138e+02,
#         1.99068653e+02, 2.23951168e+02, 2.48833684e+02, 2.73716199e+02,
#         2.98598714e+02, 3.23481230e+02, 3.48363745e+02, 3.73246260e+02,
#         3.98128776e+02, 4.23011291e+02, 4.47893806e+02, 4.72776322e+02,
#         4.97658837e+02, 5.22541352e+02, 5.47423868e+02, 5.72306383e+02,
#         5.97188898e+02, 6.22071414e+02, 6.46953929e+02, 6.71836444e+02,
#         6.96718959e+02, 7.21601475e+02, 7.46483990e+02, 7.71366505e+02,
#         7.96249021e+02, 8.21131536e+02, 8.46014051e+02, 8.70896567e+02,
#         8.95779082e+02, 9.20661597e+02, 9.45544113e+02, 9.70426628e+02,
#         9.95309143e+02, 1.02019166e+03, 1.04507417e+03, 1.06995669e+03,
#         1.09483920e+03, 1.11972172e+03, 1.14460424e+03, 1.16948675e+03,
#         1.19436927e+03, 1.21925178e+03, 1.24413430e+03, 1.26901681e+03,
#         1.29389933e+03, 1.31878184e+03, 1.34366436e+03, 1.36854687e+03,
#         1.39342939e+03, 1.41831190e+03, 1.44319442e+03, 1.46807693e+03,
#         1.49295945e+03, 1.51784197e+03, 1.54272448e+03, 1.56760700e+03,
#         1.59248951e+03, 1.61737203e+03, 1.64225454e+03, 1.66713706e+03,
#         1.69201957e+03, 1.71690209e+03, 1.74178460e+03, 1.76666712e+03,
#         1.79154963e+03, 1.81643215e+03, 1.84131466e+03, 1.86619718e+03,
#         1.89107970e+03, 1.91596221e+03, 1.94084473e+03, 1.96572724e+03,
#         1.99060976e+03, 2.01549227e+03, 2.04037479e+03, 2.06525730e+03,
#         2.09013982e+03, 2.11502233e+03, 2.13990485e+03, 2.16478736e+03,
#         2.18966988e+03, 2.21455239e+03, 2.23943491e+03, 2.26431742e+03,
#         2.28919994e+03, 2.31408246e+03, 2.33896497e+03, 2.36384749e+03,
#         2.38873000e+03, 2.41361252e+03, 2.43849503e+03, 2.46337755e+03,
#         2.48826006e+03]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
from scipy.stats import expon

# %%
# your answer here
# Hint: This is same as saying P(x<15)
exp = expon(scale = 10) 
print(exp.cdf(15))  
print(expon(scale = 10) .cdf(15))
# Out:
# 0.7768698398515702
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
1 - exp.cdf(15)
# Out:
# 0.2231301601484298
